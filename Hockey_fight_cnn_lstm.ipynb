# %% [markdown]
# # Violence Detection using CNN + LSTM neural netowrk

# %% [markdown]
# ## Introduction

# %% [markdown]
# Today, the amount of public violence has increased dramatically. As much in high schools as in the street. This has resulted in the ubiquitous use of surveillance cameras. This has helped the authorities to identify these events and take the necessary measures. But almost all systems today require the human-inspection of these videos to identify such events, which is virtually inefficient. It is therefore necessary to have such a practical system that can automatically monitor and identify the surveillance videos.
# The development of various deep learning techniques, thanks to the availability of large data sets and computational resources, has resulted in a historic change in the community of computer vision. Various techniques have been developed to address problems such as object detection, recognition, tracking, action recognition, legend generation, etc. However, despite recent developments in deep learning, very few techniques based on deep learning have been proposed to address the problem of detecting violence from videos.

# %% [markdown]
# ## Flowchart

# %% [markdown]
# The method consists of extracting a set of frames belonging to the video, sending them to a pretrained network called VGG16, obtaining the output of one of its final layers and from these outputs train another network architecture with a type of special neurons called LSTM. These neurons have memory and are able to analyze the temporal information of the video, if at any time they detect violence, it will be classified as a violent video.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import cv2
import os
import numpy as np
import keras
import matplotlib.pyplot as plt
# import download
from random import shuffle
from tensorflow.keras.applications import VGG16
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Activation
import sys
import h5py

# %%
keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# We will use the function ```print_progress``` to print the amount of videos processed the datasets

# %%
def print_progress(count, max_count):
    # Percentage completion.
    pct_complete = count / max_count

    # Status-message. Note the \r which means the line should
    # overwrite itself.
    msg = "\r- Progress: {0:.1%}".format(pct_complete)

    # Print it.
    sys.stdout.write(msg)
    sys.stdout.flush()

# %% [markdown]
# ## Load Data
#
# Firstly, we define the directory to place the video dataset

# %%
in_dir = "../input/hockey-fight-vidoes/data"

# %% [markdown]
# Copy some of the data-dimensions for convenience.

# %%
# Frame size  
img_size = 224

img_size_touple = (img_size, img_size)

# Number of channels (RGB)
num_channels = 3

# Flat frame size
img_size_flat = img_size * img_size * num_channels

# Number of classes for classification (Violence-No Violence)
num_classes = 2

# Number of files to train
_num_files_train = 1

# Number of frames per video
_images_per_file = 20

# Number of frames per training set
_num_images_train = _num_files_train * _images_per_file

# Video extension
video_exts = ".avi"

# %% [markdown]
# ### Helper-function for getting video frames
# Function used to get 20 frames from a video file and convert the frame to a suitable format for the neural net.

# %%
def get_frames(current_dir, file_name):
    
    in_file = os.path.join(current_dir, file_name)
    
    images = []
    
    vidcap = cv2.VideoCapture(in_file)
    
    success,image = vidcap.read()
        
    count = 0

    while count<_images_per_file:
                
        RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
        res = cv2.resize(RGB_img, dsize=(img_size, img_size),
                                 interpolation=cv2.INTER_CUBIC)
    
        images.append(res)
    
        success,image = vidcap.read()
    
        count += 1
        
    resul = np.array(images)
    
    resul = (resul / 255.).astype(np.float16)
        
    return resul

# %% [markdown]
# ### Helper function to get the names of the data downloaded and label it

# %%
def label_video_names(in_dir):
    
    # list containing video names
    names = []
    # list containin video labels [1, 0] if it has violence and [0, 1] if not
    labels = []
    
    
    for current_dir, dir_names,file_names in os.walk(in_dir):
        
        for file_name in file_names:
            
            if file_name[0:2] == 'fi':
                labels.append([1,0])
                names.append(file_name)
            elif file_name[0:2] == 'no':
                labels.append([0,1])
                names.append(file_name)
                     
            
    c = list(zip(names,labels))
    # Suffle the data (names and labels)
    shuffle(c)
    
    names, labels = zip(*c)
            
    return names, labels

# %% [markdown]
# ### Plot a video frame to see if data is correct

# %%
# First get the names and labels of the whole videos
names, labels = label_video_names(in_dir)

# %% [markdown]
# Then we are going to load 20 frames of one video, for example

# %%
names[12]
# Out:
# 'no123_xvid.avi'

# %% [markdown]
# The video has violence, look at the name of the video, starts with 'fi'

# %%
frames = get_frames(in_dir, names[12])

# %% [markdown]
# Convert back the frames to uint8 pixel format to plot the frame

# %%
visible_frame = (frames*255).astype('uint8')

# %%
plt.imshow(visible_frame[3])

# %%
plt.imshow(visible_frame[15])

# %% [markdown]
# ## Pre-Trained Model: VGG16

# %% [markdown]
# The following creates an instance of the pre-trained VGG16 model using the Keras API. This automatically downloads the required files if you don't have them already.
#
# The VGG16 model contains a convolutional part and a fully-connected (or dense) part which is used for classification. If include_top=True then the whole VGG16 model is downloaded which is about 528 MB. If include_top=False then only the convolutional part of the VGG16 model is downloaded which is just 57 MB.

# %%
image_model = VGG16(include_top=True, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 21s 0us/step

# %% [markdown]
# Let's see the model summary

# %%
image_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We can observe the shape of the tensors expected as input by the pre-trained VGG16 model. In this case it is images of shape 224 x 224 x 3. Note that we have defined the frame size as 224x224x3. The video frame will be the input of the VGG16 net.

# %% [markdown]
# ### VGG16 model flowchart

# %% [markdown]
# The following chart shows how the data flows when using the VGG16 model for Transfer Learning. First we input and process 20 video frames in batch with the VGG16 model. Just prior to the final classification layer of the VGG16 model, we save the so-called Transfer Values to a cache-file.
#
# The reason for using a cache-file is that it takes a long time to process an image with the VGG16 model. If each image is processed more than once then we can save a lot of time by caching the transfer-values.
#
# When all the videos have been processed through the VGG16 model and the resulting transfer-values saved to a cache file, then we can use those transfer-values as the input to LSTM neural network. We will then train the second neural network using the classes from the violence dataset (Violence, No-Violence), so the network learns how to classify images based on the transfer-values from the VGG16 model.

# %%
# We will use the output of the layer prior to the final
# classification-layer which is named fc2. This is a fully-connected (or dense) layer.
transfer_layer = image_model.get_layer('fc2')

image_model_transfer = Model(inputs=image_model.input,
                             outputs=transfer_layer.output)

transfer_values_size = K.int_shape(transfer_layer.output)[1]


print("The input of the VGG16 net have dimensions:",K.int_shape(image_model.input)[1:3])

print("The output of the selecter layer of VGG16 net have dimensions: ", transfer_values_size)
# Out:
# The input of the VGG16 net have dimensions: (224, 224)
# The output of the selecter layer of VGG16 net have dimensions:  4096

# %% [markdown]
# ### Function to process 20 video frames through VGG16 and get transfer values

# %%
def get_transfer_values(current_dir, file_name):
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    image_batch = np.zeros(shape=shape, dtype=np.float16)
    
    image_batch = get_frames(current_dir, file_name)
      
    # Pre-allocate output-array for transfer-values.
    # Note that we use 16-bit floating-points to save memory.
    shape = (_images_per_file, transfer_values_size)
    transfer_values = np.zeros(shape=shape, dtype=np.float16)

    transfer_values = \
            image_model_transfer.predict(image_batch)
            
    return transfer_values

# %% [markdown]
# ### Generator that process one video through VGG16 each function call

# %%
def proces_transfer(vid_names, in_dir, labels):
    
    count = 0
    
    tam = len(vid_names)
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    while count<tam:
        
        video_name = vid_names[count]
        
        image_batch = np.zeros(shape=shape, dtype=np.float16)
    
        image_batch = get_frames(in_dir, video_name)
        
         # Note that we use 16-bit floating-points to save memory.
        shape = (_images_per_file, transfer_values_size)
        transfer_values = np.zeros(shape=shape, dtype=np.float16)
        
        transfer_values = \
            image_model_transfer.predict(image_batch)
         
        labels1 = labels[count]
        
        aux = np.ones([20,2])
        
        labelss = labels1*aux
        
        yield transfer_values, labelss
        
        count+=1

# %% [markdown]
# ### Functions to save transfer values from VGG16 to later use
# We are going to define functions to get the transfer values from VGG16 with defined number of files. Then save the transfer values files used from training in one file and the ones uses for testing in another one.

# %%
def make_files(n_files):
    
    gen = proces_transfer(names_training, in_dir, labels_training)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('prueba.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            numer += 1

# %%
def make_files_test(n_files):
    
    gen = proces_transfer(names_test, in_dir, labels_test)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('pruebavalidation.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            numer += 1

# %% [markdown]
# ### Split the dataset into training set and test set
# We are going to split the dataset into training set and testing. The training set is used to train the model and the test set to check the model accuracy.

# %%
training_set = int(len(names)*0.8)
test_set = int(len(names)*0.2)

names_training = names[0:training_set]
names_test = names[training_set:]

labels_training = labels[0:training_set]
labels_test = labels[training_set:]

# %% [markdown]
# Then we are going to process all video frames through VGG16 and save the transfer values.

# %%
make_files(training_set)
# Out:
# - Progress: 99.9%

# %%
make_files_test(test_set)
# Out:
# - Progress: 99.5%

# %% [markdown]
# ### Load the cached transfer values into memory
# We have already saved all the videos transfer values into disk. But we have to load those transfer values into memory in order to train the LSTM net. One question would be: why not process transfer values and load them into RAM memory? Yes is a more eficient way to train the second net. But if you have to train the LSTM in different ways in order to see which way gets the best accuracy, if you didn't save the transfer values into disk you would have to process the whole videos each training. It's very time consuming processing the videos through VGG16 net.

# %% [markdown]
# In order to load the saved transfer values into RAM memory we are going to use this two functions:

# %%
def process_alldata_training():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('prueba.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %%
def process_alldata_test():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('pruebavalidation.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %%
data, target = process_alldata_training()

# %%
data_test, target_test = process_alldata_test()

# %% [markdown]
# ##Recurrent Neural Network

# %% [markdown]
# The basic building block in a Recurrent Neural Network (RNN) is a Recurrent Unit (RU). There are many different variants of recurrent units such as the rather clunky LSTM (Long-Short-Term-Memory) and the somewhat simpler GRU (Gated Recurrent Unit) which we will use in this tutorial. Experiments in the literature suggest that the LSTM and GRU have roughly similar performance. Even simpler variants also exist and the literature suggests that they may perform even better than both LSTM and GRU, but they are not implemented in Keras which we will use in this tutorial.
#
# A recurrent neuron has an internal state that is being updated every time the unit receives a new input. This internal state serves as a kind of memory. However, it is not a traditional kind of computer memory which stores bits that are either on or off. Instead the recurrent unit stores floating-point values in its memory-state, which are read and written using matrix-operations so the operations are all differentiable. This means the memory-state can store arbitrary floating-point values (although typically limited between -1.0 and 1.0) and the network can be trained like a normal neural network using Gradient Descent.

# %% [markdown]
# ### Define LSTM architecture

# %% [markdown]
# When defining the LSTM architecture we have to take into account the dimensions of the transfer values. From each frame the VGG16 network obtains as output a vector of 4096 transfer values. From each video we are processing 20 frames so we will have 20 x 4096 values per video. The classification must be done taking into account the 20 frames of the video. If any of them detects violence, the video will be classified as violent.

# %% [markdown]
# The first input dimension of LSTM neurons is the temporal dimension, in our case it is 20. The second is the size of the features vector (transfer values).

# %%
from keras.layers import LSTM, Dense, Activation, Dropout, BatchNormalization, LeakyReLU, Bidirectional
from keras.optimizers import Adam

chunk_size = 4096
n_chunks = 20
rnn_size = 512

model = Sequential()
model.add(Bidirectional(LSTM(rnn_size, input_shape=(n_chunks, chunk_size))))
model.add(Dropout(0.3))  # Dropout to prevent overfitting
model.add(Dense(1024))
model.add(BatchNormalization())  # Normalize inputs to dense layer
model.add(LeakyReLU(alpha=0.01))  # Leaky ReLU activation
model.add(Dense(50))
model.add(Activation('sigmoid'))
model.add(Dense(2))
model.add(Activation('softmax'))

# Compile with gradient clipping and categorical cross-entropy
optimizer = Adam(clipvalue=1.0)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ## Model training

# %%
epoch = 200
batchS = 500

history = model.fit(np.array(data[0:720]), np.array(target[0:720]), epochs=epoch,
                    validation_data=(np.array(data[720:]), np.array(target[720:])), 
                    batch_size=batchS, verbose=2)
# Out:
# Epoch 1/200
# 2/2 - 5s - loss: 0.7235 - accuracy: 0.5667 - val_loss: 0.6455 - val_accuracy: 0.8625
# Epoch 2/200
# 2/2 - 0s - loss: 0.6629 - accuracy: 0.5597 - val_loss: 0.5660 - val_accuracy: 0.8000
# Epoch 3/200
# 2/2 - 0s - loss: 0.4526 - accuracy: 0.8264 - val_loss: 0.4749 - val_accuracy: 0.8250
# Epoch 4/200
# 2/2 - 0s - loss: 0.3639 - accuracy: 0.8556 - val_loss: 0.5351 - val_accuracy: 0.6750
# Epoch 5/200
# 2/2 - 0s - loss: 0.3414 - accuracy: 0.8764 - val_loss: 0.4085 - val_accuracy: 0.8500
# Epoch 6/200
# 2/2 - 0s - loss: 0.3306 - accuracy: 0.8764 - val_loss: 0.3048 - val_accuracy: 0.8750
# Epoch 7/200
# 2/2 - 0s - loss: 0.3137 - accuracy: 0.8958 - val_loss: 0.2916 - val_accuracy: 0.9375
# Epoch 8/200
# 2/2 - 0s - loss: 0.3092 - accuracy: 0.8875 - val_loss: 0.2788 - val_accuracy: 0.9375
# Epoch 9/200
# 2/2 - 0s - loss: 0.3037 - accuracy: 0.9014 - val_loss: 0.2634 - val_accuracy: 0.9250
# Epoch 10/200
# 2/2 - 0s - loss: 0.2896 - accuracy: 0.8986 - val_loss: 0.2508 - val_accuracy: 0.9250
# Epoch 11/200
# 2/2 - 0s - loss: 0.2961 - accuracy: 0.9042 - val_loss: 0.3456 - val_accuracy: 0.8625
# Epoch 12/200
# 2/2 - 0s - loss: 0.2915 - accuracy: 0.8972 - val_loss: 0.3593 - val_accuracy: 0.8625
# Epoch 13/200
# 2/2 - 0s - loss: 0.2716 - accuracy: 0.9028 - val_loss: 0.4406 - val_accuracy: 0.8000
# Epoch 14/200
# 2/2 - 0s - loss: 0.2729 - accuracy: 0.9056 - val_loss: 0.4357 - val_accuracy: 0.8000
# Epoch 15/200
# 2/2 - 0s - loss: 0.2757 - accuracy: 0.9042 - val_loss: 0.3708 - val_accuracy: 0.8375
# Epoch 16/200
# 2/2 - 0s - loss: 0.2656 - accuracy: 0.9083 - val_loss: 0.3455 - val_accuracy: 0.8625
# Epoch 17/200
# 2/2 - 0s - loss: 0.2475 - accuracy: 0.9236 - val_loss: 0.3534 - val_accuracy: 0.8375
# Epoch 18/200
# 2/2 - 0s - loss: 0.2579 - accuracy: 0.9153 - val_loss: 0.3625 - val_accuracy: 0.8375
# Epoch 19/200
# 2/2 - 0s - loss: 0.2494 - accuracy: 0.9167 - val_loss: 0.2872 - val_accuracy: 0.8875
# Epoch 20/200
# 2/2 - 0s - loss: 0.2653 - accuracy: 0.9056 - val_loss: 0.2792 - val_accuracy: 0.8875
# Epoch 21/200
# 2/2 - 0s - loss: 0.2450 - accuracy: 0.9236 - val_loss: 0.2345 - val_accuracy: 0.9125
# Epoch 22/200
# 2/2 - 0s - loss: 0.2283 - accuracy: 0.9333 - val_loss: 0.1910 - val_accuracy: 0.9500
# Epoch 23/200
# 2/2 - 0s - loss: 0.2285 - accuracy: 0.9250 - val_loss: 0.1728 - val_accuracy: 0.9750
# Epoch 24/200
# 2/2 - 0s - loss: 0.2304 - accuracy: 0.9333 - val_loss: 0.2014 - val_accuracy: 0.9250
# Epoch 25/200
# 2/2 - 0s - loss: 0.2206 - accuracy: 0.9264 - val_loss: 0.1927 - val_accuracy: 0.9250
# Epoch 26/200
# 2/2 - 0s - loss: 0.2168 - accuracy: 0.9333 - val_loss: 0.1828 - val_accuracy: 0.9625
# Epoch 27/200
# 2/2 - 0s - loss: 0.2075 - accuracy: 0.9417 - val_loss: 0.2278 - val_accuracy: 0.9125
# Epoch 28/200
# 2/2 - 0s - loss: 0.2143 - accuracy: 0.9333 - val_loss: 0.1898 - val_accuracy: 0.9625
# Epoch 29/200
# 2/2 - 0s - loss: 0.2032 - accuracy: 0.9306 - val_loss: 0.1995 - val_accuracy: 0.9250
# Epoch 30/200
# 2/2 - 0s - loss: 0.2119 - accuracy: 0.9444 - val_loss: 0.1929 - val_accuracy: 0.9375
# Epoch 31/200
# 2/2 - 0s - loss: 0.2061 - accuracy: 0.9292 - val_loss: 0.1536 - val_accuracy: 0.9500
# Epoch 32/200
# 2/2 - 0s - loss: 0.1945 - accuracy: 0.9361 - val_loss: 0.1529 - val_accuracy: 0.9500
# Epoch 33/200
# 2/2 - 0s - loss: 0.1980 - accuracy: 0.9472 - val_loss: 0.2541 - val_accuracy: 0.8750
# Epoch 34/200
# 2/2 - 0s - loss: 0.1971 - accuracy: 0.9431 - val_loss: 0.3065 - val_accuracy: 0.8750
# Epoch 35/200
# 2/2 - 0s - loss: 0.1972 - accuracy: 0.9389 - val_loss: 0.1505 - val_accuracy: 0.9500
# Epoch 36/200
# 2/2 - 0s - loss: 0.1904 - accuracy: 0.9431 - val_loss: 0.3231 - val_accuracy: 0.8750
# Epoch 37/200
# 2/2 - 0s - loss: 0.1794 - accuracy: 0.9500 - val_loss: 0.4425 - val_accuracy: 0.8250
# Epoch 38/200
# 2/2 - 0s - loss: 0.1896 - accuracy: 0.9444 - val_loss: 0.2174 - val_accuracy: 0.9125
# Epoch 39/200
# 2/2 - 0s - loss: 0.1924 - accuracy: 0.9403 - val_loss: 0.1559 - val_accuracy: 0.9625
# Epoch 40/200
# 2/2 - 0s - loss: 0.1916 - accuracy: 0.9361 - val_loss: 0.2766 - val_accuracy: 0.8875
# Epoch 41/200
# 2/2 - 0s - loss: 0.1851 - accuracy: 0.9458 - val_loss: 0.2953 - val_accuracy: 0.8875
# Epoch 42/200
# 2/2 - 0s - loss: 0.1787 - accuracy: 0.9486 - val_loss: 0.2134 - val_accuracy: 0.9125
# Epoch 43/200
# 2/2 - 0s - loss: 0.1807 - accuracy: 0.9472 - val_loss: 0.3066 - val_accuracy: 0.8875
# Epoch 44/200
# 2/2 - 0s - loss: 0.1881 - accuracy: 0.9472 - val_loss: 0.1697 - val_accuracy: 0.9500
# Epoch 45/200
# 2/2 - 0s - loss: 0.1735 - accuracy: 0.9486 - val_loss: 0.1609 - val_accuracy: 0.9500
# Epoch 46/200
# 2/2 - 0s - loss: 0.1708 - accuracy: 0.9514 - val_loss: 0.2462 - val_accuracy: 0.9125
# Epoch 47/200
# 2/2 - 0s - loss: 0.1676 - accuracy: 0.9556 - val_loss: 0.1647 - val_accuracy: 0.9500
# Epoch 48/200
# 2/2 - 0s - loss: 0.1675 - accuracy: 0.9542 - val_loss: 0.1710 - val_accuracy: 0.9375
# Epoch 49/200
# 2/2 - 0s - loss: 0.1702 - accuracy: 0.9500 - val_loss: 0.1338 - val_accuracy: 0.9500
# Epoch 50/200
# 2/2 - 0s - loss: 0.1526 - accuracy: 0.9542 - val_loss: 0.1389 - val_accuracy: 0.9500
# Epoch 51/200
# 2/2 - 0s - loss: 0.1613 - accuracy: 0.9583 - val_loss: 0.1310 - val_accuracy: 0.9500
# Epoch 52/200
# 2/2 - 0s - loss: 0.1617 - accuracy: 0.9542 - val_loss: 0.1394 - val_accuracy: 0.9375
# Epoch 53/200
# 2/2 - 0s - loss: 0.1641 - accuracy: 0.9542 - val_loss: 0.2458 - val_accuracy: 0.9125
# Epoch 54/200
# 2/2 - 0s - loss: 0.1593 - accuracy: 0.9528 - val_loss: 0.1421 - val_accuracy: 0.9500
# Epoch 55/200
# 2/2 - 0s - loss: 0.1647 - accuracy: 0.9514 - val_loss: 0.1328 - val_accuracy: 0.9500
# Epoch 56/200
# 2/2 - 0s - loss: 0.1464 - accuracy: 0.9597 - val_loss: 0.1564 - val_accuracy: 0.9500
# Epoch 57/200
# 2/2 - 0s - loss: 0.1557 - accuracy: 0.9472 - val_loss: 0.1594 - val_accuracy: 0.9250
# Epoch 58/200
# 2/2 - 0s - loss: 0.1490 - accuracy: 0.9528 - val_loss: 0.1353 - val_accuracy: 0.9500
# Epoch 59/200
# 2/2 - 0s - loss: 0.1668 - accuracy: 0.9486 - val_loss: 0.2843 - val_accuracy: 0.8750
# Epoch 60/200
# 2/2 - 0s - loss: 0.1534 - accuracy: 0.9542 - val_loss: 0.1361 - val_accuracy: 0.9500
# Epoch 61/200
# 2/2 - 0s - loss: 0.1562 - accuracy: 0.9528 - val_loss: 0.1346 - val_accuracy: 0.9625
# Epoch 62/200
# 2/2 - 0s - loss: 0.1433 - accuracy: 0.9542 - val_loss: 0.1301 - val_accuracy: 0.9500
# Epoch 63/200
# 2/2 - 0s - loss: 0.1368 - accuracy: 0.9583 - val_loss: 0.1559 - val_accuracy: 0.9250
# Epoch 64/200
# 2/2 - 0s - loss: 0.1381 - accuracy: 0.9583 - val_loss: 0.4878 - val_accuracy: 0.8000
# Epoch 65/200
# 2/2 - 0s - loss: 0.1507 - accuracy: 0.9597 - val_loss: 0.3719 - val_accuracy: 0.8500
# Epoch 66/200
# 2/2 - 0s - loss: 0.1523 - accuracy: 0.9486 - val_loss: 0.1542 - val_accuracy: 0.9250
# Epoch 67/200
# 2/2 - 0s - loss: 0.1405 - accuracy: 0.9583 - val_loss: 0.2317 - val_accuracy: 0.8875
# Epoch 68/200
# 2/2 - 0s - loss: 0.1369 - accuracy: 0.9625 - val_loss: 0.2501 - val_accuracy: 0.8875
# Epoch 69/200
# 2/2 - 0s - loss: 0.1264 - accuracy: 0.9639 - val_loss: 0.1415 - val_accuracy: 0.9625
# Epoch 70/200
# 2/2 - 0s - loss: 0.1331 - accuracy: 0.9639 - val_loss: 0.2670 - val_accuracy: 0.8750
# Epoch 71/200
# 2/2 - 0s - loss: 0.1185 - accuracy: 0.9667 - val_loss: 0.2519 - val_accuracy: 0.9000
# Epoch 72/200
# 2/2 - 0s - loss: 0.1331 - accuracy: 0.9556 - val_loss: 0.3853 - val_accuracy: 0.8500
# Epoch 73/200
# 2/2 - 0s - loss: 0.1309 - accuracy: 0.9611 - val_loss: 0.1348 - val_accuracy: 0.9625
# Epoch 74/200
# 2/2 - 0s - loss: 0.1105 - accuracy: 0.9708 - val_loss: 0.1862 - val_accuracy: 0.9000
# Epoch 75/200
# 2/2 - 0s - loss: 0.1204 - accuracy: 0.9653 - val_loss: 0.2939 - val_accuracy: 0.8875
# Epoch 76/200
# 2/2 - 0s - loss: 0.1172 - accuracy: 0.9597 - val_loss: 0.2251 - val_accuracy: 0.9125
# Epoch 77/200
# 2/2 - 0s - loss: 0.1118 - accuracy: 0.9667 - val_loss: 0.2115 - val_accuracy: 0.9375
# Epoch 78/200
# 2/2 - 0s - loss: 0.1138 - accuracy: 0.9611 - val_loss: 0.1507 - val_accuracy: 0.9250
# Epoch 79/200
# 2/2 - 0s - loss: 0.1183 - accuracy: 0.9694 - val_loss: 0.3076 - val_accuracy: 0.8625
# Epoch 80/200
# 2/2 - 0s - loss: 0.1229 - accuracy: 0.9625 - val_loss: 0.1736 - val_accuracy: 0.9375
# Epoch 81/200
# 2/2 - 0s - loss: 0.1039 - accuracy: 0.9708 - val_loss: 0.2366 - val_accuracy: 0.8875
# Epoch 82/200
# 2/2 - 0s - loss: 0.1031 - accuracy: 0.9708 - val_loss: 0.1570 - val_accuracy: 0.9375
# Epoch 83/200
# 2/2 - 0s - loss: 0.1025 - accuracy: 0.9653 - val_loss: 0.1963 - val_accuracy: 0.9250
# Epoch 84/200
# 2/2 - 0s - loss: 0.1072 - accuracy: 0.9653 - val_loss: 0.2138 - val_accuracy: 0.9250
# Epoch 85/200
# 2/2 - 0s - loss: 0.1162 - accuracy: 0.9625 - val_loss: 0.2094 - val_accuracy: 0.9250
# Epoch 86/200
# 2/2 - 0s - loss: 0.1036 - accuracy: 0.9667 - val_loss: 0.1575 - val_accuracy: 0.9250
# Epoch 87/200
# 2/2 - 0s - loss: 0.1158 - accuracy: 0.9639 - val_loss: 0.6047 - val_accuracy: 0.7875
# Epoch 88/200
# 2/2 - 0s - loss: 0.1231 - accuracy: 0.9556 - val_loss: 0.3157 - val_accuracy: 0.9000
# Epoch 89/200
# 2/2 - 0s - loss: 0.1320 - accuracy: 0.9472 - val_loss: 0.2010 - val_accuracy: 0.9250
# Epoch 90/200
# 2/2 - 0s - loss: 0.1508 - accuracy: 0.9444 - val_loss: 0.1868 - val_accuracy: 0.9250
# Epoch 91/200
# 2/2 - 0s - loss: 0.1368 - accuracy: 0.9514 - val_loss: 0.1553 - val_accuracy: 0.9250
# Epoch 92/200
# 2/2 - 0s - loss: 0.1478 - accuracy: 0.9472 - val_loss: 0.2796 - val_accuracy: 0.9000
# Epoch 93/200
# 2/2 - 0s - loss: 0.1333 - accuracy: 0.9542 - val_loss: 0.1550 - val_accuracy: 0.9375
# Epoch 94/200
# 2/2 - 0s - loss: 0.1166 - accuracy: 0.9639 - val_loss: 0.2138 - val_accuracy: 0.9125
# Epoch 95/200
# 2/2 - 0s - loss: 0.1450 - accuracy: 0.9500 - val_loss: 0.1539 - val_accuracy: 0.9500
# Epoch 96/200
# 2/2 - 0s - loss: 0.1199 - accuracy: 0.9667 - val_loss: 0.1601 - val_accuracy: 0.9375
# Epoch 97/200
# 2/2 - 0s - loss: 0.1035 - accuracy: 0.9667 - val_loss: 0.1697 - val_accuracy: 0.9500
# Epoch 98/200
# 2/2 - 0s - loss: 0.1222 - accuracy: 0.9542 - val_loss: 0.1737 - val_accuracy: 0.9500
# Epoch 99/200
# 2/2 - 0s - loss: 0.1215 - accuracy: 0.9639 - val_loss: 0.3072 - val_accuracy: 0.8750
# Epoch 100/200
# 2/2 - 0s - loss: 0.1181 - accuracy: 0.9611 - val_loss: 0.1854 - val_accuracy: 0.9500
# Epoch 101/200
# 2/2 - 0s - loss: 0.1142 - accuracy: 0.9611 - val_loss: 0.1826 - val_accuracy: 0.9500
# Epoch 102/200
# 2/2 - 0s - loss: 0.1080 - accuracy: 0.9667 - val_loss: 0.2326 - val_accuracy: 0.8875
# Epoch 103/200
# 2/2 - 0s - loss: 0.1048 - accuracy: 0.9639 - val_loss: 0.1948 - val_accuracy: 0.9375
# Epoch 104/200
# 2/2 - 0s - loss: 0.0953 - accuracy: 0.9681 - val_loss: 0.2292 - val_accuracy: 0.9125
# Epoch 105/200
# 2/2 - 0s - loss: 0.0978 - accuracy: 0.9708 - val_loss: 0.1734 - val_accuracy: 0.9500
# Epoch 106/200
# 2/2 - 0s - loss: 0.0983 - accuracy: 0.9694 - val_loss: 0.1736 - val_accuracy: 0.9500
# Epoch 107/200
# 2/2 - 0s - loss: 0.0893 - accuracy: 0.9778 - val_loss: 0.1931 - val_accuracy: 0.9250
# Epoch 108/200
# 2/2 - 0s - loss: 0.0922 - accuracy: 0.9792 - val_loss: 0.1653 - val_accuracy: 0.9375
# Epoch 109/200
# 2/2 - 0s - loss: 0.1031 - accuracy: 0.9694 - val_loss: 0.2514 - val_accuracy: 0.8875
# Epoch 110/200
# 2/2 - 0s - loss: 0.0877 - accuracy: 0.9750 - val_loss: 0.3291 - val_accuracy: 0.9000
# Epoch 111/200
# 2/2 - 0s - loss: 0.1093 - accuracy: 0.9681 - val_loss: 0.5239 - val_accuracy: 0.8375
# Epoch 112/200
# 2/2 - 0s - loss: 0.1321 - accuracy: 0.9486 - val_loss: 0.1808 - val_accuracy: 0.9500
# Epoch 113/200
# 2/2 - 0s - loss: 0.0887 - accuracy: 0.9764 - val_loss: 0.2770 - val_accuracy: 0.8750
# Epoch 114/200
# 2/2 - 0s - loss: 0.0962 - accuracy: 0.9722 - val_loss: 0.2812 - val_accuracy: 0.8875
# Epoch 115/200
# 2/2 - 0s - loss: 0.1010 - accuracy: 0.9653 - val_loss: 0.1874 - val_accuracy: 0.9500
# Epoch 116/200
# 2/2 - 0s - loss: 0.0965 - accuracy: 0.9681 - val_loss: 0.2610 - val_accuracy: 0.9000
# Epoch 117/200
# 2/2 - 0s - loss: 0.0878 - accuracy: 0.9736 - val_loss: 0.4681 - val_accuracy: 0.8500
# Epoch 118/200
# 2/2 - 0s - loss: 0.1007 - accuracy: 0.9722 - val_loss: 0.1726 - val_accuracy: 0.9500
# Epoch 119/200
# 2/2 - 0s - loss: 0.0940 - accuracy: 0.9750 - val_loss: 0.1808 - val_accuracy: 0.9250
# Epoch 120/200
# 2/2 - 0s - loss: 0.1006 - accuracy: 0.9667 - val_loss: 0.2573 - val_accuracy: 0.9250
# Epoch 121/200
# 2/2 - 0s - loss: 0.0899 - accuracy: 0.9694 - val_loss: 0.1766 - val_accuracy: 0.9500
# Epoch 122/200
# 2/2 - 0s - loss: 0.0921 - accuracy: 0.9722 - val_loss: 0.1814 - val_accuracy: 0.9500
# Epoch 123/200
# 2/2 - 0s - loss: 0.0824 - accuracy: 0.9792 - val_loss: 0.2121 - val_accuracy: 0.9375
# Epoch 124/200
# 2/2 - 0s - loss: 0.0765 - accuracy: 0.9806 - val_loss: 0.2112 - val_accuracy: 0.9375
# Epoch 125/200
# 2/2 - 0s - loss: 0.0799 - accuracy: 0.9750 - val_loss: 0.4470 - val_accuracy: 0.8500
# Epoch 126/200
# 2/2 - 0s - loss: 0.0902 - accuracy: 0.9806 - val_loss: 0.2347 - val_accuracy: 0.9375
# Epoch 127/200
# 2/2 - 0s - loss: 0.0872 - accuracy: 0.9722 - val_loss: 0.4174 - val_accuracy: 0.8500
# Epoch 128/200
# 2/2 - 0s - loss: 0.0755 - accuracy: 0.9819 - val_loss: 0.1909 - val_accuracy: 0.9375
# Epoch 129/200
# 2/2 - 0s - loss: 0.0727 - accuracy: 0.9806 - val_loss: 0.1950 - val_accuracy: 0.9500
# Epoch 130/200
# 2/2 - 0s - loss: 0.0746 - accuracy: 0.9833 - val_loss: 0.1946 - val_accuracy: 0.9500
# Epoch 131/200
# 2/2 - 0s - loss: 0.0831 - accuracy: 0.9792 - val_loss: 0.4593 - val_accuracy: 0.8375
# Epoch 132/200
# 2/2 - 0s - loss: 0.0978 - accuracy: 0.9694 - val_loss: 0.2772 - val_accuracy: 0.8875
# Epoch 133/200
# 2/2 - 0s - loss: 0.0897 - accuracy: 0.9736 - val_loss: 0.1972 - val_accuracy: 0.9500
# Epoch 134/200
# 2/2 - 0s - loss: 0.1022 - accuracy: 0.9569 - val_loss: 0.2410 - val_accuracy: 0.9250
# Epoch 135/200
# 2/2 - 0s - loss: 0.0790 - accuracy: 0.9750 - val_loss: 0.2437 - val_accuracy: 0.8875
# Epoch 136/200
# 2/2 - 0s - loss: 0.0604 - accuracy: 0.9847 - val_loss: 0.1711 - val_accuracy: 0.9375
# Epoch 137/200
# 2/2 - 0s - loss: 0.0978 - accuracy: 0.9722 - val_loss: 0.1901 - val_accuracy: 0.9500
# Epoch 138/200
# 2/2 - 0s - loss: 0.0837 - accuracy: 0.9708 - val_loss: 0.2028 - val_accuracy: 0.9375
# Epoch 139/200
# 2/2 - 0s - loss: 0.0746 - accuracy: 0.9764 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 140/200
# 2/2 - 0s - loss: 0.0842 - accuracy: 0.9764 - val_loss: 0.1900 - val_accuracy: 0.9500
# Epoch 141/200
# 2/2 - 0s - loss: 0.0703 - accuracy: 0.9792 - val_loss: 0.1943 - val_accuracy: 0.9500
# Epoch 142/200
# 2/2 - 0s - loss: 0.0750 - accuracy: 0.9750 - val_loss: 0.1903 - val_accuracy: 0.9500
# Epoch 143/200
# 2/2 - 0s - loss: 0.0632 - accuracy: 0.9861 - val_loss: 0.2418 - val_accuracy: 0.9250
# Epoch 144/200
# 2/2 - 0s - loss: 0.0637 - accuracy: 0.9861 - val_loss: 0.3100 - val_accuracy: 0.8875
# Epoch 145/200
# 2/2 - 0s - loss: 0.0848 - accuracy: 0.9708 - val_loss: 0.2840 - val_accuracy: 0.9000
# Epoch 146/200
# 2/2 - 0s - loss: 0.0805 - accuracy: 0.9778 - val_loss: 0.6657 - val_accuracy: 0.8375
# Epoch 147/200
# 2/2 - 0s - loss: 0.1230 - accuracy: 0.9556 - val_loss: 0.8993 - val_accuracy: 0.7125
# Epoch 148/200
# 2/2 - 0s - loss: 0.1249 - accuracy: 0.9625 - val_loss: 0.1846 - val_accuracy: 0.9500
# Epoch 149/200
# 2/2 - 0s - loss: 0.0915 - accuracy: 0.9764 - val_loss: 0.2033 - val_accuracy: 0.9250
# Epoch 150/200
# 2/2 - 0s - loss: 0.1119 - accuracy: 0.9639 - val_loss: 0.2586 - val_accuracy: 0.9125
# Epoch 151/200
# 2/2 - 0s - loss: 0.1033 - accuracy: 0.9681 - val_loss: 0.1894 - val_accuracy: 0.9375
# Epoch 152/200
# 2/2 - 0s - loss: 0.0978 - accuracy: 0.9653 - val_loss: 0.4323 - val_accuracy: 0.8750
# Epoch 153/200
# 2/2 - 0s - loss: 0.0740 - accuracy: 0.9722 - val_loss: 0.1758 - val_accuracy: 0.9500
# Epoch 154/200
# 2/2 - 0s - loss: 0.0851 - accuracy: 0.9694 - val_loss: 0.3406 - val_accuracy: 0.8750
# Epoch 155/200
# 2/2 - 0s - loss: 0.0620 - accuracy: 0.9778 - val_loss: 0.4068 - val_accuracy: 0.8750
# Epoch 156/200
# 2/2 - 0s - loss: 0.0777 - accuracy: 0.9764 - val_loss: 0.2654 - val_accuracy: 0.9000
# Epoch 157/200
# 2/2 - 0s - loss: 0.0778 - accuracy: 0.9750 - val_loss: 0.5604 - val_accuracy: 0.8625
# Epoch 158/200
# 2/2 - 0s - loss: 0.0939 - accuracy: 0.9681 - val_loss: 0.2036 - val_accuracy: 0.9125
# Epoch 159/200
# 2/2 - 0s - loss: 0.0895 - accuracy: 0.9736 - val_loss: 0.2571 - val_accuracy: 0.9000
# Epoch 160/200
# 2/2 - 0s - loss: 0.0733 - accuracy: 0.9722 - val_loss: 0.3062 - val_accuracy: 0.8750
# Epoch 161/200
# 2/2 - 0s - loss: 0.0732 - accuracy: 0.9764 - val_loss: 0.3712 - val_accuracy: 0.8750
# Epoch 162/200
# 2/2 - 0s - loss: 0.0886 - accuracy: 0.9681 - val_loss: 0.3107 - val_accuracy: 0.8750
# Epoch 163/200
# 2/2 - 0s - loss: 0.0696 - accuracy: 0.9778 - val_loss: 0.1946 - val_accuracy: 0.9500
# Epoch 164/200
# 2/2 - 0s - loss: 0.0733 - accuracy: 0.9806 - val_loss: 0.3557 - val_accuracy: 0.9000
# Epoch 165/200
# 2/2 - 0s - loss: 0.0926 - accuracy: 0.9722 - val_loss: 0.3608 - val_accuracy: 0.8750
# Epoch 166/200
# 2/2 - 0s - loss: 0.0938 - accuracy: 0.9667 - val_loss: 0.3056 - val_accuracy: 0.8750
# Epoch 167/200
# 2/2 - 0s - loss: 0.0764 - accuracy: 0.9764 - val_loss: 0.2904 - val_accuracy: 0.8875
# Epoch 168/200
# 2/2 - 0s - loss: 0.0638 - accuracy: 0.9819 - val_loss: 0.2077 - val_accuracy: 0.9250
# Epoch 169/200
# 2/2 - 0s - loss: 0.0791 - accuracy: 0.9750 - val_loss: 0.2125 - val_accuracy: 0.9500
# Epoch 170/200
# 2/2 - 0s - loss: 0.0607 - accuracy: 0.9819 - val_loss: 0.2111 - val_accuracy: 0.9500
# Epoch 171/200
# 2/2 - 0s - loss: 0.0756 - accuracy: 0.9806 - val_loss: 0.2335 - val_accuracy: 0.9250
# Epoch 172/200
# 2/2 - 0s - loss: 0.0758 - accuracy: 0.9792 - val_loss: 0.3864 - val_accuracy: 0.8750
# Epoch 173/200
# 2/2 - 0s - loss: 0.0610 - accuracy: 0.9833 - val_loss: 0.2266 - val_accuracy: 0.9250
# Epoch 174/200
# 2/2 - 0s - loss: 0.0603 - accuracy: 0.9819 - val_loss: 0.2281 - val_accuracy: 0.9250
# Epoch 175/200
# 2/2 - 0s - loss: 0.0570 - accuracy: 0.9819 - val_loss: 0.5322 - val_accuracy: 0.8625
# Epoch 176/200
# 2/2 - 0s - loss: 0.0679 - accuracy: 0.9833 - val_loss: 0.2543 - val_accuracy: 0.9125
# Epoch 177/200
# 2/2 - 0s - loss: 0.0617 - accuracy: 0.9764 - val_loss: 0.2191 - val_accuracy: 0.9500
# Epoch 178/200
# 2/2 - 0s - loss: 0.0650 - accuracy: 0.9833 - val_loss: 0.5410 - val_accuracy: 0.8750
# Epoch 179/200
# 2/2 - 0s - loss: 0.0657 - accuracy: 0.9792 - val_loss: 0.2875 - val_accuracy: 0.9250
# Epoch 180/200
# 2/2 - 0s - loss: 0.0897 - accuracy: 0.9708 - val_loss: 0.3472 - val_accuracy: 0.8875
# Epoch 181/200
# 2/2 - 0s - loss: 0.0618 - accuracy: 0.9792 - val_loss: 0.2738 - val_accuracy: 0.9375
# Epoch 182/200
# 2/2 - 0s - loss: 0.0767 - accuracy: 0.9764 - val_loss: 0.2163 - val_accuracy: 0.9500
# Epoch 183/200
# 2/2 - 0s - loss: 0.0535 - accuracy: 0.9806 - val_loss: 0.4276 - val_accuracy: 0.8875
# Epoch 184/200
# 2/2 - 0s - loss: 0.0907 - accuracy: 0.9625 - val_loss: 0.2103 - val_accuracy: 0.9375
# Epoch 185/200
# 2/2 - 0s - loss: 0.0686 - accuracy: 0.9792 - val_loss: 0.2388 - val_accuracy: 0.9250
# Epoch 186/200
# 2/2 - 0s - loss: 0.0436 - accuracy: 0.9875 - val_loss: 0.2591 - val_accuracy: 0.9250
# Epoch 187/200
# 2/2 - 0s - loss: 0.0644 - accuracy: 0.9764 - val_loss: 0.3397 - val_accuracy: 0.9000
# Epoch 188/200
# 2/2 - 0s - loss: 0.0775 - accuracy: 0.9750 - val_loss: 0.2308 - val_accuracy: 0.9500
# Epoch 189/200
# 2/2 - 0s - loss: 0.0722 - accuracy: 0.9722 - val_loss: 0.2960 - val_accuracy: 0.9125
# Epoch 190/200
# 2/2 - 0s - loss: 0.0712 - accuracy: 0.9778 - val_loss: 0.4537 - val_accuracy: 0.8750
# Epoch 191/200
# 2/2 - 0s - loss: 0.0653 - accuracy: 0.9778 - val_loss: 0.3964 - val_accuracy: 0.8500
# Epoch 192/200
# 2/2 - 0s - loss: 0.0798 - accuracy: 0.9778 - val_loss: 0.2244 - val_accuracy: 0.9125
# Epoch 193/200
# 2/2 - 0s - loss: 0.0541 - accuracy: 0.9833 - val_loss: 0.2988 - val_accuracy: 0.9250
# Epoch 194/200
# 2/2 - 0s - loss: 0.1017 - accuracy: 0.9653 - val_loss: 0.3196 - val_accuracy: 0.9250
# Epoch 195/200
# 2/2 - 0s - loss: 0.0546 - accuracy: 0.9847 - val_loss: 0.2598 - val_accuracy: 0.9375
# Epoch 196/200
# 2/2 - 0s - loss: 0.0664 - accuracy: 0.9764 - val_loss: 0.3293 - val_accuracy: 0.9125
# Epoch 197/200
# 2/2 - 0s - loss: 0.0612 - accuracy: 0.9819 - val_loss: 0.2439 - val_accuracy: 0.9375
# Epoch 198/200
# 2/2 - 0s - loss: 0.0611 - accuracy: 0.9833 - val_loss: 0.2243 - val_accuracy: 0.9250
# Epoch 199/200
# 2/2 - 0s - loss: 0.0791 - accuracy: 0.9708 - val_loss: 0.4304 - val_accuracy: 0.9000
# Epoch 200/200
# 2/2 - 0s - loss: 0.0832 - accuracy: 0.9778 - val_loss: 0.2710 - val_accuracy: 0.9125

# %% [markdown]
# ## Test the model

# %% [markdown]
# We are going to test the model with 20 % of the total videos. This videos have not been used to train the network.

# %%
result = model.evaluate(np.array(data_test), np.array(target_test))
# Out:
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1603 - accuracy: 0.9500

# %% [markdown]
# ## Print the model accuracy

# %%
for name, value in zip(model.metrics_names, result):
    print(name, value)
# Out:
# loss 0.16030818223953247
# accuracy 0.949999988079071

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path.eps', format='eps', dpi=1000)
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path1.eps', format='eps', dpi=1000)
plt.show()

# %%
import shutil

# Zip the entire working directory
shutil.make_archive('/kaggle/working/your_archive', 'zip', '/kaggle/working/')

# The zip file will be available for download in the Output tab
# Out:
# '/kaggle/working/your_archive.zip'
